# %% [markdown]
# # Graduate Admission Prediction in Foreign Country

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score

# %%
admission=pd.read_csv("C:\\Users\\Abhishek\\Desktop\\datasets\\Admission_Predict.csv")
admission.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admission.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
c=admission.corr()
c
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %%
sns.heatmap(c)

# %%
sns.pairplot(admission.iloc[:,[-1,0]])

# %%
sns.pairplot(admission.iloc[:,[-1,1]])

# %%
sns.pairplot(admission.iloc[:,[-1,2]])

# %%
sns.pairplot(admission.iloc[:,[-1,3]])

# %%
sns.pairplot(admission.iloc[:,[-1,4]])

# %%
sns.pairplot(admission.iloc[:,[-1,5]])

# %%
sns.pairplot(admission.iloc[:,[-1,6]])

# %%
sns.pairplot(admission.iloc[:,[-1,7]])

# %%
x=admission.iloc[:,:8]
y=admission.iloc[:,8]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=14,test_size=0.10)

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([ 0.00016254,  0.00175312,  0.00379118,  0.0084295 , -0.00138485,
#         0.02235564,  0.10531156,  0.02579644])

# %%
reg.intercept_
# Out:
# -1.2898239202198407

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([0.69161902, 0.58982097, 0.77285611, 0.5313418 , 0.8399207 ,
#        0.9393336 , 0.52976326, 0.65582462, 0.79468274, 0.54829162,
#        0.88572181, 0.60662012, 0.76780985, 0.90677456, 0.97197857,
#        0.75449054, 0.75696046, 0.92066841, 0.47518147, 0.57985242,
#        0.50450368, 0.70766787, 0.78867356, 0.50635598, 0.63764582,
#        0.862707  , 0.8889403 , 0.70470589, 0.72202492, 0.60223233,
#        0.8854079 , 0.81760109, 0.57371686, 0.854289  , 0.6558506 ,
#        0.82548703, 0.66292642, 0.85847294, 0.73193628, 0.84580703])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9165075481679555

# %%
'''ts_score=[]
for j in range (100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.10)
    lr=LinearRegression().fit(x_train,y_train)
    ts_score.append(lr.score(x_test,y_test))
k=ts_score.index(np.max(ts_score))'''

# %%
#k
# Out:
# 14

# %% [markdown]
# #  Decision Tree Regression

# %%
from sklearn import tree 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=48,test_size=0.10)

# %%
from sklearn.tree import DecisionTreeRegressor
regression_tree=DecisionTreeRegressor(min_samples_split=0.03)
regression_tree.fit(x_train,y_train)
y_pred=regression_tree.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9055589058308658

# %%
'''ts_score=[]
for j in range (100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.10)
    lr=DecisionTreeRegressor().fit(x_train,y_train)
    ts_score.append(lr.score(x_test,y_test))
k=ts_score.index(np.max(ts_score))'''

# %%
#k
# Out:
# 48

# %% [markdown]
# #  Random Forest regression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=14,test_size=0.10)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=11,random_state=32)
regressor.fit(x_train,y_train)
y_pred_rf=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_rf)
# Out:
# 0.9153428238084951

# %%
'''ts_score=[]
for j in range (100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.10)
    lr=RandomForestRegressor().fit(x_train,y_train)
    ts_score.append(lr.score(x_test,y_test))
k=ts_score.index(np.max(ts_score))'''
# Out:
# C:\Users\Abhishek\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Abhishek\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Abhishek\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Abhishek\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
#k
# Out:
# 14
